-- %% [markdown]
-- # [dbo].[Nvd_ChiTietDonHang]

-- %%
USE [K22CNT2_NguyenVanDuoc_2210900016_Project3]
GO

-- %%
/****** Object:  Table [dbo].[Nvd_ChiTietDonHang]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_ChiTietDonHang](
	[NvdMaDH] [int] NOT NULL,
	[NvdMaSP] [int] NOT NULL,
	[NvdSoLuong] [int] NULL,
	[NvdGiaBan] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaDH] ASC,
	[NvdMaSP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_DonHang]

-- %%
/****** Object:  Table [dbo].[Nvd_DonHang]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_DonHang](
	[NvdMaDH] [int] NOT NULL,
	[NvdMaKH] [int] NULL,
	[NvdMaNV] [int] NULL,
	[NvdNgayDat] [date] NULL,
	[NvdTongTien] [decimal](12, 2) NULL,
	[NvdTrangThai] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaDH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_KhachHang]

-- %%
/****** Object:  Table [dbo].[Nvd_KhachHang]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_KhachHang](
	[NvdMaKH] [int] NOT NULL,
	[NvdHoTen] [nvarchar](100) NULL,
	[NvdEmail] [varchar](100) NULL,
	[NvdSoDienThoai] [varchar](15) NULL,
	[NvdDiaChi] [text] NULL,
	[NvdTrangThai] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaKH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_NhanVien]

-- %%
/****** Object:  Table [dbo].[Nvd_NhanVien]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_NhanVien](
	[NvdMaNV] [int] NOT NULL,
	[NvdTenNV] [nvarchar](100) NULL,
	[NvdChucVu] [varchar](50) NULL,
	[NvdLuong] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaNV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_QuanTri]

-- %%
/****** Object:  Table [dbo].[Nvd_QuanTri]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_QuanTri](
	[Id] [int] NOT NULL,
	[NvdTaiKhoan] [nvarchar](50) NULL,
	[NvdMatKhau] [nvarchar](50) NULL,
	[NvdEmail] [nvarchar](100) NULL,
	[NvdSoDT] [varchar](15) NULL,
	[NvdNgayTao] [date] NULL,
	[NvdTrangThai] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_SanPham]

-- %%
/****** Object:  Table [dbo].[Nvd_SanPham]    Script Date: 2/25/2025 8:24:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nvd_SanPham](
	[NvdMaSP] [int] NOT NULL,
	[NvdTenSP] [nvarchar](50) NULL,
	[NvdSoLuong] [int] NULL,
	[NvdNgayNhap] [datetime] NULL,
	[NvdDVT] [nvarchar](20) NULL,
	[NvdDonGia] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[NvdMaSP] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nvd_ChiTietDonHang]

-- %%
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (1, 1, 2, CAST(25000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (1, 3, 1, CAST(8000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (2, 2, 1, CAST(22000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (3, 1, 1, CAST(25000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (3, 3, 2, CAST(8000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (4, 4, 1, CAST(15000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (5, 3, 1, CAST(8000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_ChiTietDonHang] ([NvdMaDH], [NvdMaSP], [NvdSoLuong], [NvdGiaBan]) VALUES (5, 5, 2, CAST(12000000.00 AS Decimal(10, 2)))
GO

-- %% [markdown]
-- # [dbo].[Nvd_DonHang]

-- %%
INSERT [dbo].[Nvd_DonHang] ([NvdMaDH], [NvdMaKH], [NvdMaNV], [NvdNgayDat], [NvdTongTien], [NvdTrangThai]) VALUES (1, 1, 2, CAST(N'2024-02-15' AS Date), CAST(58000000.00 AS Decimal(12, 2)), 1)
INSERT [dbo].[Nvd_DonHang] ([NvdMaDH], [NvdMaKH], [NvdMaNV], [NvdNgayDat], [NvdTongTien], [NvdTrangThai]) VALUES (2, 2, 1, CAST(N'2024-02-16' AS Date), CAST(22000000.00 AS Decimal(12, 2)), 0)
INSERT [dbo].[Nvd_DonHang] ([NvdMaDH], [NvdMaKH], [NvdMaNV], [NvdNgayDat], [NvdTongTien], [NvdTrangThai]) VALUES (3, 3, 3, CAST(N'2024-02-17' AS Date), CAST(41000000.00 AS Decimal(12, 2)), 1)
INSERT [dbo].[Nvd_DonHang] ([NvdMaDH], [NvdMaKH], [NvdMaNV], [NvdNgayDat], [NvdTongTien], [NvdTrangThai]) VALUES (4, 4, 4, CAST(N'2024-02-18' AS Date), CAST(15000000.00 AS Decimal(12, 2)), 1)
INSERT [dbo].[Nvd_DonHang] ([NvdMaDH], [NvdMaKH], [NvdMaNV], [NvdNgayDat], [NvdTongTien], [NvdTrangThai]) VALUES (5, 5, 5, CAST(N'2024-02-19' AS Date), CAST(37000000.00 AS Decimal(12, 2)), 1)
GO

-- %% [markdown]
-- # [dbo].[Nvd_KhachHang]

-- %%
INSERT [dbo].[Nvd_KhachHang] ([NvdMaKH], [NvdHoTen], [NvdEmail], [NvdSoDienThoai], [NvdDiaChi], [NvdTrangThai]) VALUES (1, N'Nguyen Van Luong', N'vanluong342@gmail.com', N'0912345678', N'Ha Noi', 1)
INSERT [dbo].[Nvd_KhachHang] ([NvdMaKH], [NvdHoTen], [NvdEmail], [NvdSoDienThoai], [NvdDiaChi], [NvdTrangThai]) VALUES (2, N'Tran Thi Bich', N'bichtran644@gmail.com', N'0987654321', N'TP Ho Chi Minh', 1)
INSERT [dbo].[Nvd_KhachHang] ([NvdMaKH], [NvdHoTen], [NvdEmail], [NvdSoDienThoai], [NvdDiaChi], [NvdTrangThai]) VALUES (3, N'Le Cao Nam', N'namcao966@gmail.com', N'0905123456', N'Da Nang', 0)
INSERT [dbo].[Nvd_KhachHang] ([NvdMaKH], [NvdHoTen], [NvdEmail], [NvdSoDienThoai], [NvdDiaChi], [NvdTrangThai]) VALUES (4, N'Pham Hong Son', N'sonpham756@gmail.com', N'0906778899', N'Hai Phong', 1)
INSERT [dbo].[Nvd_KhachHang] ([NvdMaKH], [NvdHoTen], [NvdEmail], [NvdSoDienThoai], [NvdDiaChi], [NvdTrangThai]) VALUES (5, N'Nguyen Thi Mai', N'mainguyen833@gmail.com', N'0934556677', N'Can Tho', 1)
GO

-- %% [markdown]
-- # [dbo].[Nvd_NhanVien]

-- %%
INSERT [dbo].[Nvd_NhanVien] ([NvdMaNV], [NvdTenNV], [NvdChucVu], [NvdLuong]) VALUES (1, N'Pham Van Duong', N'TruongPhong', CAST(15000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_NhanVien] ([NvdMaNV], [NvdTenNV], [NvdChucVu], [NvdLuong]) VALUES (2, N'Hoang Thi Xuan', N'NhanVien', CAST(10000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_NhanVien] ([NvdMaNV], [NvdTenNV], [NvdChucVu], [NvdLuong]) VALUES (3, N'Bui Van Ta', N'PhoPhong', CAST(12000000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_NhanVien] ([NvdMaNV], [NvdTenNV], [NvdChucVu], [NvdLuong]) VALUES (4, N'Le Thi Hoa', N'NhanVien', CAST(9500000.00 AS Decimal(10, 2)))
INSERT [dbo].[Nvd_NhanVien] ([NvdMaNV], [NvdTenNV], [NvdChucVu], [NvdLuong]) VALUES (5, N'Tran Van Long', N'PhoPhong', CAST(11000000.00 AS Decimal(10, 2)))
GO

-- %% [markdown]
-- # [dbo].[Nvd_QuanTri]

-- %%
INSERT [dbo].[Nvd_QuanTri] ([Id], [NvdTaiKhoan], [NvdMatKhau], [NvdEmail], [NvdSoDT], [NvdNgayTao], [NvdTrangThai]) VALUES (1, N'DuocNguyen', N'220605', N'duocnguyen@gmail.com', N'0911222333', CAST(N'2024-02-01' AS Date), 1)
INSERT [dbo].[Nvd_QuanTri] ([Id], [NvdTaiKhoan], [NvdMatKhau], [NvdEmail], [NvdSoDT], [NvdNgayTao], [NvdTrangThai]) VALUES (2, N'Admin', N'123456@', N'admin@gmail.com', N'0988777666', CAST(N'2024-02-05' AS Date), 0)
GO

-- %% [markdown]
-- # [dbo].[Nvd_SanPham]

-- %%
INSERT [dbo].[Nvd_SanPham] ([NvdMaSP], [NvdTenSP], [NvdSoLuong], [NvdNgayNhap], [NvdDVT], [NvdDonGia]) VALUES (1, N'May massege mini', 50, CAST(N'2024-02-01T00:00:00.000' AS DateTime), N'Chiec', 25000000)
INSERT [dbo].[Nvd_SanPham] ([NvdMaSP], [NvdTenSP], [NvdSoLuong], [NvdNgayNhap], [NvdDVT], [NvdDonGia]) VALUES (2, N'May do huyet ap', 30, CAST(N'2024-02-05T00:00:00.000' AS DateTime), N'Chiec', 22000000)
INSERT [dbo].[Nvd_SanPham] ([NvdMaSP], [NvdTenSP], [NvdSoLuong], [NvdNgayNhap], [NvdDVT], [NvdDonGia]) VALUES (3, N'May tho oxi', 40, CAST(N'2024-02-08T00:00:00.000' AS DateTime), N'Chiec', 8000000)
INSERT [dbo].[Nvd_SanPham] ([NvdMaSP], [NvdTenSP], [NvdSoLuong], [NvdNgayNhap], [NvdDVT], [NvdDonGia]) VALUES (4, N'May khu khuan', 20, CAST(N'2024-02-10T00:00:00.000' AS DateTime), N'Chiec', 15000000)
INSERT [dbo].[Nvd_SanPham] ([NvdMaSP], [NvdTenSP], [NvdSoLuong], [NvdNgayNhap], [NvdDVT], [NvdDonGia]) VALUES (5, N'May do duong huyet', 25, CAST(N'2024-02-12T00:00:00.000' AS DateTime), N'Chiec', 12000000)
GO

-- %% [markdown]
-- # [FK__Nvd_ChiTi__NvdMa__72C60C4A]

-- %%
ALTER TABLE [dbo].[Nvd_ChiTietDonHang]  WITH CHECK ADD FOREIGN KEY([NvdMaDH])
REFERENCES [dbo].[Nvd_DonHang] ([NvdMaDH])
GO

-- %% [markdown]
-- # [FK__Nvd_ChiTi__NvdMa__73BA3083]

-- %%
ALTER TABLE [dbo].[Nvd_ChiTietDonHang]  WITH CHECK ADD FOREIGN KEY([NvdMaSP])
REFERENCES [dbo].[Nvd_SanPham] ([NvdMaSP])
GO

-- %% [markdown]
-- # [FK__Nvd_DonHa__NvdMa__6EF57B66]

-- %%
ALTER TABLE [dbo].[Nvd_DonHang]  WITH CHECK ADD FOREIGN KEY([NvdMaKH])
REFERENCES [dbo].[Nvd_KhachHang] ([NvdMaKH])
GO

-- %% [markdown]
-- # [FK__Nvd_DonHa__NvdMa__6FE99F9F]

-- %%
ALTER TABLE [dbo].[Nvd_DonHang]  WITH CHECK ADD FOREIGN KEY([NvdMaNV])
REFERENCES [dbo].[Nvd_NhanVien] ([NvdMaNV])
GO
